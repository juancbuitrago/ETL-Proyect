# %% [markdown]
# #

# %%
import matplotlib.pyplot as plt
import numpy as np
import json
import pandas as pd
import seaborn as sns
import sys

# %%
# Save data into dataframe
metacritic_df = pd.read_csv('../data/metacritic_data.csv')
rawg_df = pd.read_csv('../data/rawg_data.csv')

# %%
metacritic_df.head()
# Out:
#                           title    released                    developer  \
# 0                     ZIGGURAT   2012-02-17  ACTION BUTTON ENTERTAINMENT
# 1                     4X4 EVO 2  2001-11-15             TERMINAL REALITY
# 2                     MOTOGP 2   2002-01-22                        NAMCO
# 3                      GOTHIC 3  2006-11-14                PIRANHA BYTES
# 4  SIEGE SURVIVAL GLORIA VICTIS  2021-05-18               FISHTANKSTUDIO
#
#          publisher           genres                rating  user_score  \
# 0     FRESHUU INC.           ACTION                   NaN         6.9
# 1        GATHERING  AUTO RACING SIM  RATED E FOR EVERYONE         0.0
# 2            NAMCO  AUTO RACING SIM  RATED E FOR EVERYONE         5.8
# 3            ASPYR      WESTERN RPG      RATED T FOR TEEN         7.5
# 4  BLACK EYE GAMES              RPG                   NaN         6.5
#
#    ratings_count          platforms
# 0             14  IOS (IPHONE/IPAD)
# ...

# %%
rawg_df.head()
# Out:
#                               title    released        rating  ratings_count  \
# 0                GRAND THEFT AUTO V  2013-09-17        MATURE           6781
# 1          THE WITCHER 3: WILD HUNT  2015-05-18        MATURE           6494
# 2                          PORTAL 2  2011-04-18  EVERYONE 10+           5619
# 3  COUNTER-STRIKE: GLOBAL OFFENSIVE  2012-08-21        MATURE           3448
# 4                TOMB RAIDER (2013)  2013-03-05        MATURE           3867
#
#          platforms   genres
# 0               PC   ACTION
# 1  XBOX SERIES S/X   ACTION
# 2    PLAYSTATION 3  SHOOTER
# 3               PC  SHOOTER
# 4    PLAYSTATION 4   ACTION

# %%
print(metacritic_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14055 entries, 0 to 14054
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          14034 non-null  object
#  1   released       13991 non-null  object
#  2   developer      13917 non-null  object
#  3   publisher      13917 non-null  object
#  4   genres         14034 non-null  object
#  5   rating         11005 non-null  object
#  6   user_score     14055 non-null  float64
#  7   ratings_count  14055 non-null  int64
#  8   platforms      14026 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 988.4+ KB
# None

# %%
print(rawg_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          1000 non-null   object
#  1   released       1000 non-null   object
#  2   rating         737 non-null    object
#  3   ratings_count  1000 non-null   int64
#  4   platforms      996 non-null    object
#  5   genres         999 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB
# None

# %%
metacritic_df['title'] = metacritic_df['title'].str.upper()
rawg_df['title'] = rawg_df['title'].str.upper()

# Merge the two DataFrames on the 'title' column
merged_data = pd.merge(metacritic_df, rawg_df, how='outer', on='title')

# Inspect the result

print("Number of register:", merged_data.shape[0])
merged_data.head()
# Out:
# Number of register: 14513
#                    title  released_x            developer  \
# 0          'SPLOSION MAN  2009-07-22  TWISTED PIXEL GAMES
# 1  0 DAY ATTACK ON EARTH  2009-12-23                GULTI
# 2            007 LEGENDS  2012-10-16              EUROCOM
# 3          007 NIGHTFIRE  2002-11-18              EUROCOM
# 4  007 QUANTUM OF SOLACE  2008-11-04             TREYARCH
#
#              publisher              genres_x                      rating_x  \
# 0  TWISTED PIXEL GAMES         2D PLATFORMER  RATED E +10 FOR EVERYONE +10
# 1          SQUARE ENIX  THIRD PERSON SHOOTER  RATED E +10 FOR EVERYONE +10
# 2           ACTIVISION                   FPS              RATED T FOR TEEN
# 3      ELECTRONIC ARTS                   FPS              RATED T FOR TEEN
# 4           ACTIVISION                   FPS              RATED T FOR TEEN
#
#    user_score  ratings_count_x platforms_x released_y rating_y  \
# 0         7.3             91.0    XBOX 360        NaN      NaN
# ...

# %%
merged_data.to_csv('../data/merge_data.csv', index=False)

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14513 entries, 0 to 14512
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            14492 non-null  object
#  1   released_x       13991 non-null  object
#  2   developer        13917 non-null  object
#  3   publisher        13917 non-null  object
#  4   genres_x         14034 non-null  object
#  5   rating_x         11005 non-null  object
#  6   user_score       14055 non-null  float64
#  7   ratings_count_x  14055 non-null  float64
#  8   platforms_x      14026 non-null  object
#  9   released_y       1000 non-null   object
#  10  rating_y         737 non-null    object
#  11  ratings_count_y  1000 non-null   float64
#  12  platforms_y      996 non-null    object
#  13  genres_y         999 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 1.6+ MB
